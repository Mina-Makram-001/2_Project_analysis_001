# %% [markdown]
# ## 📌 Pandas `pd.concat()` Cheat Sheet
#
# The **`pd.concat()`** function is used to **concatenate** (combine) multiple DataFrames or Series along a particular axis (row-wise or column-wise).
#
# ---
#
# ## 🔹 Syntax
# ```python
# pd.concat(
#     objs,
#     axis=0,
#     join="outer",
#     ignore_index=False,
#     keys=None,
#     levels=None,
#     names=None,
#     verify_integrity=False,
#     sort=False,
#     copy=True
# )
#
# > Important Options
# - axis=0 → stack rows (default).
# - axis=1 → add columns side by side.
# - ignore_index=True → resets index numbers.
# - join="outer" → keeps all columns, fill missing with NaN.
# - join="inner" → only keeps common columns.
# - keys=["df1","df2"] → adds labels so you know which row came from which DataFrame.
#
# > Easy Summary
# - concat = combine DataFrames.
# - axis=0 = vertical (new rows).
# - axis=1 = horizontal (new columns).
# - Use ignore_index=True if you don’t care about old index numbers.
# - Use join="inner" if you only want the overlapping columns.

# %%
import numpy as np
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt


# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#data cleanup
df['job_posted_date']=pd.to_datetime(df['job_posted_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')

# %%
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
months= df['job_posted_month'].unique()
months
# Out:
# array(['Jun', 'Jan', 'Oct', 'Jul', 'Aug', 'Nov', 'Mar', 'Dec', 'Apr',
#        'Feb', 'Sep', 'May'], dtype=object)

# %% [markdown]
# ### note
#
# 1️⃣ General structure of a dictionary comprehension
#
# ```{ key_expr : value_expr for item in iterable if condition }```
#
#
# key_expr → what will be used as the dictionary key.
#
# value_expr → what will be used as the dictionary value.
#
# for item in iterable → loop, like in a normal for.
#
# if condition → optional filter, just like list comprehensions.
#
# ## vs
#
# 2️⃣ General structure of a list comprehension
#
# ```[ value_expr for item in iterable if condition ]```
#
#
# value_expr → what each element in the list will look like.
#
# for item in iterable → loop, like a normal for.
#
# if condition → optional filter to include/exclude elements.

# %%
"""dict_months = {
'Jan': df_jan,
'Feb': df_feb,
'Mar': df_mar,
'Apr': df_apr,
'May': df_may,
'Jun': df_jun,
'Jul': df_jul,
'Aug': df_aug,
'Sep': df_sep,
'Oct': df_oct,
'Nov': df_nov,
'Dec': df_dec
}"""

dict_monthes= {month: df[df['job_posted_month'] == month] for month in months}
dict_monthes['Jan'] # Example to access January
# Out:
#           job_title_short                                  job_title  \
# 1            Data Analyst                               Data Analyst
# 20         Data Scientist                             Data Scientist
# 39          Data Engineer                              Data Engineer
# 53          Data Engineer                              Data Engineer
# 55         Data Scientist                             Data Scientist
# ...                   ...                                        ...
# 785699  Software Engineer                        Simulation Engineer
# 785700      Data Engineer                       Data Engineer Ssr/Sr
# 785703       Data Analyst    Data Analyst - CRYPTOGRAPHY - Full-time
# 785704   Business Analyst                           Business Analyst
# 785705       Data Analyst  Expert Business Data Analyst - Now Hiring
#
#                                  job_location             job_via  \
# 1                Guadalajara, Jalisco, Mexico    via BeBee México
# ...

# %% [markdown]
# ## id boss need the first 1/4 of the year

# %%
df_q1= pd.concat([dict_monthes['Jan'], dict_monthes['Feb'], dict_monthes['Mar']], ignore_index=True) #ignore_index=True to reset index
df_q1
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 1          Data Scientist                                     Data Scientist
# 2           Data Engineer                                      Data Engineer
# 3           Data Engineer                                      Data Engineer
# 4          Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 220479  Software Engineer                                    DevOps Engineer
# 220480       Data Analyst                                   CRM Data Analyst
# 220481   Business Analyst                     Commercial Analyst - Start Now
# 220482      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 220483  Software Engineer                                 AWS System Analyst
#
# ...

# %%
df_q1['job_posted_month'].value_counts().plot(kind='bar')
plt.title('Number of Job Posts in Q1')
plt.ylabel('Number of Job Posts')
plt.xlabel('Month')
plt.show()
